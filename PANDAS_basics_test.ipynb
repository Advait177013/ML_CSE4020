# %% [markdown]
# <a href="https://colab.research.google.com/github/Advait177013/ML_CSE4020/blob/main/PANDAS_basics_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
list1 = ["S1", "S2", "S3", "S4", "S5"]
name = ["Fang Yuan", "Wang Lin", "Han Xiao", "Linley Farlier", "Shin Young-woo"]
novel = ["Reverend Insanity", "Renegade Immortal", "The Legendary Mechanic", "Warlock of the Magus WOrld", "Overgeared"]

titles=["Index Val", "MC Name", "Novel Name"]
values = [list1, name, novel]
result = list(zip(titles, values))
result
# Out:
# [('Index Val', ['S1', 'S2', 'S3', 'S4', 'S5']),
#  ('MC Name',
#   ['Fang Yuan', 'Wang Lin', 'Han Xiao', 'Linley Farlier', 'Shin Young-woo']),
#  ('Novel Name',
#   ['Reverend Insanity',
#    'Renegade Immortal',
#    'The Legendary Mechanic',
#    'Warlock of the Magus WOrld',
#    'Overgeared'])]

# %%
dicres = dict(result)
df1=pandas.DataFrame(dicres)
df1
# Out:
#   Index Val         MC Name                  Novel Name
# 0        S1       Fang Yuan           Reverend Insanity
# 1        S2        Wang Lin           Renegade Immortal
# 2        S3        Han Xiao      The Legendary Mechanic
# 3        S4  Linley Farlier  Warlock of the Magus WOrld
# 4        S5  Shin Young-woo                  Overgeared

# %%
df2=pandas.read_csv('/content/sample_data/california_housing_test.csv')
df2.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df2.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
df2.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# ...

# %%
df1.to_csv('/content/sample_data/my_test.csv')

# %%
df1.set_index("Novel Name")
# Out:
#                            Index Val         MC Name
# Novel Name
# Reverend Insanity                 S1       Fang Yuan
# Renegade Immortal                 S2        Wang Lin
# The Legendary Mechanic            S3        Han Xiao
# Warlock of the Magus WOrld        S4  Linley Farlier
# Overgeared                        S5  Shin Young-woo

# %%
print(df1.info, "\n")
print(type(df1))
# Out:
# <bound method DataFrame.info of   Index Val         MC Name                  Novel Name
# 0        S1       Fang Yuan           Reverend Insanity
# 1        S2        Wang Lin           Renegade Immortal
# 2        S3        Han Xiao      The Legendary Mechanic
# 3        S4  Linley Farlier  Warlock of the Magus WOrld
# 4        S5  Shin Young-woo                  Overgeared>
#
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df2.shape)
df2.drop_duplicates()
print(df2.shape)
# Out:
# (3000, 9)
# (3000, 9)

# %%
data1={
    "Index Val" : ["S6", "S7"],
    "MC Name" : ["Kim Dokja", "Lu Yun"],
    "Novel Name" : ["Omniscient Reader's Viewpoint", "Necropolis Immortal"]
}
df3=pandas.DataFrame(data1)
print("df1\n")
df1
# Out:
# df1
#   Index Val         MC Name                  Novel Name
# 0        S1       Fang Yuan           Reverend Insanity
# 1        S2        Wang Lin           Renegade Immortal
# 2        S3        Han Xiao      The Legendary Mechanic
# 3        S4  Linley Farlier  Warlock of the Magus WOrld
# 4        S5  Shin Young-woo                  Overgeared

# %%
print("df2\n")
df3
# Out:
# df2
#   Index Val    MC Name                     Novel Name
# 0        S6  Kim Dokja  Omniscient Reader's Viewpoint
# 1        S7     Lu Yun            Necropolis Immortal

# %%
print("apended\n")
df1=df1.append(df3)
df1
# Out:
# apended
#   Index Val         MC Name                     Novel Name
# 0        S1       Fang Yuan              Reverend Insanity
# 1        S2        Wang Lin              Renegade Immortal
# 2        S3        Han Xiao         The Legendary Mechanic
# 3        S4  Linley Farlier     Warlock of the Magus WOrld
# 4        S5  Shin Young-woo                     Overgeared
# 0        S6       Kim Dokja  Omniscient Reader's Viewpoint
# 1        S7          Lu Yun            Necropolis Immortal

# %%
print(df2.columns)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df2.rename(columns={"population" : "pop"}, inplace=True)
print(df2.columns)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'pop', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df1.describe()
# Out:
#        Index Val    MC Name         Novel Name
# count          7          7                  7
# unique         7          7                  7
# top           S1  Fang Yuan  Reverend Insanity
# freq           1          1                  1

# %%
print(df1['MC Name'].count())
print(df1['MC Name'].nunique())
print(df1['MC Name'].unique())
# Out:
# 7
# 7
# ['Fang Yuan' 'Wang Lin' 'Han Xiao' 'Linley Farlier' 'Shin Young-woo'
#  'Kim Dokja' 'Lu Yun']

# %%
print(df1.iloc[0:7, 1:3])
# Out:
#           MC Name                     Novel Name
# 0       Fang Yuan              Reverend Insanity
# 1        Wang Lin              Renegade Immortal
# 2        Han Xiao         The Legendary Mechanic
# 3  Linley Farlier     Warlock of the Magus WOrld
# 4  Shin Young-woo                     Overgeared
# 0       Kim Dokja  Omniscient Reader's Viewpoint
# 1          Lu Yun            Necropolis Immortal

# %%
df1.set_index('MC Name', inplace=True)
print(df1.loc['Han Xiao', 'Novel Name'])
# Out:
# The Legendary Mechanic

# %%
df4=df2['median_house_value']>500000
df4.head()
df5=df2[df4]
df5.head()
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 42     -118.06     34.15                37.0       1980.0           226.0
# 117    -122.07     37.34                30.0       1851.0           238.0
# 118    -117.18     33.02                15.0       3540.0           453.0
# 128    -122.47     37.79                52.0       2844.0           623.0
# 135    -122.34     37.56                39.0       3562.0           391.0
#
#         pop  households  median_income  median_house_value
# 42    697.0       226.0        15.0001            500001.0
# 117   631.0       236.0        10.1007            500001.0
# 118  1364.0       425.0        13.6623            500001.0
# 128  1380.0       596.0         4.7500            500001.0
# 135  1139.0       391.0        12.6417            500001.0

# %%
import numpy 
df6=df2.groupby("median_house_value").agg({"households":numpy.sum, "total_bedrooms":numpy.sum, "pop":numpy.sum})
df6.head()
# Out:
#                     households  total_bedrooms     pop
# median_house_value
# 22500.0                  375.0           451.0  1230.0
# 37500.0                   49.0           102.0   140.0
# 39200.0                  220.0           237.0   772.0
# 39800.0                  241.0           316.0   672.0
# 40000.0                  274.0           290.0   413.0

# %%
df6.plot(x='households', y='pop', kind='bar')
